# %% [markdown]
# ### Importando as bibliotecas Pandas e Nunmpy

# %%
# Para facilitar no desenvolvimento, "apelidamos" as bibliotecas
import pandas as pd
import numpy as np

# %% [markdown]
# ### Criando o DataFrame com os dados do arquivo .csv

# %%
# pasta_arquivo = "/Users/felipealbanez/Data Analytics/CAIXA Verso/Técnicas de Programação I (PY)/Projeto Final/consulta_cand_2022_BRASIL.csv"
#dados_tse_2022 = pd.read_csv(pasta_arquivo)
#dados_tse_2022.head()

#  erro:
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc7 in position 838: invalid continuation byte

# Segunda tentativa 
# sep=';': Os dados abertos do TSE usam ponto e vírgula para separar as colunas, e não a vírgula padrão americana.
# encoding='iso-8859-1': Evita erros de leitura com acentos e caracteres da língua portuguesa.

pasta_arquivo = "/Users/felipealbanez/Data Analytics/CAIXA Verso/Técnicas de Programação I (PY)/Projeto Final/consulta_cand_2022_BRASIL.csv"
dados_tse_2022 = pd.read_csv(pasta_arquivo, sep=';', encoding='iso-8859-1')

# vizualisa as 5 primeiras linhas do dataframe
dados_tse_2022.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO      NM_TIPO_ELEICAO  \
# 0  23/08/2026   03:15:48         2022                2    ELEIÇÃO ORDINÁRIA
# 1  23/08/2026   03:15:48         2022                1  ELEIÇÃO SUPLEMENTAR
# 2  23/08/2026   03:15:48         2022                2    ELEIÇÃO ORDINÁRIA
# 3  23/08/2026   03:15:48         2022                2    ELEIÇÃO ORDINÁRIA
# 4  23/08/2026   03:15:48         2022                2    ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                           DS_ELEICAO  DT_ELEICAO  \
# 0         1         546       Eleições Gerais Estaduais 2022  02/10/2022
# 1         1        6278  Eleição Suplementar Governador 2026  21/06/2026
# 2         1         546       Eleições Gerais Estaduais 2022  02/10/2022
# 3         1         546       Eleições Gerais Estaduais 2022  02/10/2022
# 4         1         546       Eleições Gerais Estaduais 2022  02/10/2022
#
# ...

# %% [markdown]
# ### Conhecendo o DataFrame

# %%
# informa o número de linhas e colunas
print("Shape:", dados_tse_2022.shape)
# Out:
# Shape: (29322, 50)

# %% [markdown]
# ### Definindo quais colunas do Dataframe serão utililizadas

# %%
# imprimi as colunas do df
print(dados_tse_2022.columns)
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_CARGO', 'DS_CARGO',
#        'SQ_CANDIDATO', 'NR_CANDIDATO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO',
#        'NM_SOCIAL_CANDIDATO', 'NR_CPF_CANDIDATO', 'DS_EMAIL',
#        'CD_SITUACAO_CANDIDATURA', 'DS_SITUACAO_CANDIDATURA', 'TP_AGREMIACAO',
#        'NR_PARTIDO', 'SG_PARTIDO', 'NM_PARTIDO', 'NR_FEDERACAO',
#        'NM_FEDERACAO', 'SG_FEDERACAO', 'DS_COMPOSICAO_FEDERACAO',
#        'SQ_COLIGACAO', 'NM_COLIGACAO', 'DS_COMPOSICAO_COLIGACAO',
#        'SG_UF_NASCIMENTO', 'DT_NASCIMENTO', 'NR_TITULO_ELEITORAL_CANDIDATO',
#        'CD_GENERO', 'DS_GENERO', 'CD_GRAU_INSTRUCAO', 'DS_GRAU_INSTRUCAO',
#        'CD_ESTADO_CIVIL', 'DS_ESTADO_CIVIL', 'CD_COR_RACA', 'DS_COR_RACA',
#        'CD_OCUPACAO', 'DS_OCUPACAO', 'CD_SIT_TOT_TURNO', 'DS_SIT_TOT_TURNO'],
#       dtype='object')

# %%
# quais valores cada coluna possui
# unique: retorna uma lista com os valores únicos daquela coluna

ano_eleicao = dados_tse_2022['ANO_ELEICAO'].unique()
print("ANO_ELEICAO:", ano_eleicao)

cd_tipo_eleicao = dados_tse_2022['CD_TIPO_ELEICAO'].unique()
print("CD_TIPO_ELEICAO:", cd_tipo_eleicao)

cd_tipo_eleicao = dados_tse_2022['NM_TIPO_ELEICAO'].unique()
print('NM_TIPO_ELEICAO:', cd_tipo_eleicao)
# Out:
# ANO_ELEICAO: [2022]
# CD_TIPO_ELEICAO: [2 1]
# NM_TIPO_ELEICAO: ['ELEIÇÃO ORDINÁRIA' 'ELEIÇÃO SUPLEMENTAR']

# %%
# cria uma lista com os nomes das colunas

# colunas_selecionadas = []
